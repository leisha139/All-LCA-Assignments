# %%
import numpy as np


array1 = np.array([[1, 2, 3], 
                   [4, 5, 6]])

array2 = np.array([[7, 8, 9], 
                   [10, 11, 12]])

result_array = array1 + array2

print("\nSum of matrices (using NumPy):")
print(result_array)
# Out:
# Sum of matrices (using NumPy):
# [[ 8 10 12]
#  [14 16 18]]
