# %%
def is_rirght_angled(a,b,c):
    sides = sorted([a,b,c]) 

    if round(sides[0]**2 + sides[1]**2, 5) == round(sides[2]**2, 5):
        return True
    return False

a = float(input("Enter the length of the first side: "))
b = float(input("Enter the length of the second side: "))
c = float(input("Enter the length of the third side: ")) 

if is_right_angled(a, b, c):
 print("Yes! This is a right-angled triangle.")
else:
 print("No, this is not a right-angled triangle.")
# Out:
# Enter the length of the first side:  9
# Enter the length of the second side:  5
# Enter the length of the third side:  15
# No, this is not a right-angled triangle.

# %%
def is_rirght_angled(a,b,c):
    sides = sorted([a,b,c]) 

    if round(sides[0]**2 + sides[1]**2, 5) == round(sides[2]**2, 5):
        return True
    return False

a = float(input("Enter the length of the first side: "))
b = float(input("Enter the length of the second side: "))
c = float(input("Enter the length of the third side: ")) 

if is_right_angled(a, b, c):
 print("Yes! This is a right-angled triangle.")
else:
 print("No, this is not a right-angled triangle.")
# Out:
# Enter the length of the first side:  10
# Enter the length of the second side:  6
# Enter the length of the third side:  8
# Yes! This is a right-angled triangle.
